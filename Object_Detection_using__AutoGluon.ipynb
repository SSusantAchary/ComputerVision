# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1yt3NfCfp7hnXIFfSq1kk8LYKfX_X6Qxq)

# %%
# !nvidia-smi
# Out:
# Sat Dec 19 15:37:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -U pip
# !pip install mxnet-cu101 
# !pip install autogluon
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/54/eb/4a3642e971f404d69d4f6fa3885559d67562801b99d7592487f1ecc4e017/pip-20.3.3-py2.py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 18.7MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-20.3.3
# Collecting mxnet-cu101
#   Downloading mxnet_cu101-1.7.0-py2.py3-none-manylinux2014_x86_64.whl (846.0 MB)
#      |███████████████████████████████▌| 834.1 MB 1.2 MB/s eta 0:00:11tcmalloc: large alloc 1147494400 bytes == 0x38c82000 @  0x7f5e9c74c615 0x591e47 0x4cc179 0x4cc2db 0x50a1cc 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x58e683 0x50c127 0x58e683 0x50c127 0x58e683 0x50c127 0x508cd5 0x594a01 0x54a971 0x5a9dac 0x50a433 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
#      |████████████████████████████████| 846.0 MB 22 kB/s
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.6/dist-packages (from mxnet-cu101) (1.19.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from mxnet-cu101) (2.23.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet-cu101) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet-cu101) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet-cu101) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet-cu101) (3.0.4)
# Installing collected packages: graphviz, mxnet-cu101
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-cu101-1.7.0
# Collecting autogluon
#   Downloading autogluon-0.0.15-py3-none-any.whl (622 kB)
#      |████████████████████████████████| 622 kB 11.6 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from autogluon) (3.2.2)
# Requirement already satisfied: scikit-learn<0.24,>=0.22.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.22.2.post1)
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.12.0)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.8.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.23.0)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.5)
# Requirement already satisfied: psutil<=5.7.0,>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (5.4.8)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from autogluon) (3.6.4)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.19.4)
# Requirement already satisfied: pyarrow<=1.0.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.14.1)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.6/dist-packages (from autogluon) (5.1.1)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (4.41.1)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.1.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.29.21)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.4.1)
# Collecting fastparquet==0.4.1
#   Downloading fastparquet-0.4.1.tar.gz (28.6 MB)
#      |████████████████████████████████| 28.6 MB 35 kB/s
# Requirement already satisfied: numba>=0.28 in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.4.1->autogluon) (0.48.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.4.1->autogluon) (20.8)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.4.1->autogluon) (1.15.0)
# Collecting catboost<0.25,>=0.23.0
#   Downloading catboost-0.24.3-cp36-none-manylinux1_x86_64.whl (66.3 MB)
#      |████████████████████████████████| 66.3 MB 21 kB/s
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from catboost<0.25,>=0.23.0->autogluon) (4.4.1)
# Collecting ConfigSpace<=0.4.10
#   Downloading ConfigSpace-0.4.10.tar.gz (882 kB)
#      |████████████████████████████████| 882 kB 58.2 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from ConfigSpace<=0.4.10->autogluon) (2.4.7)
# Collecting cryptography>=2.8
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 50.0 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.8->autogluon) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography>=2.8->autogluon) (2.20)
# Collecting distributed>=2.6.0
#   Downloading distributed-2020.12.0-py3-none-any.whl (669 kB)
#      |████████████████████████████████| 669 kB 66.8 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (3.13)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (2.3.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (50.3.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (1.7.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (0.11.1)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (1.0.1)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (2.0.0)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dask>=2.6.0
#   Downloading dask-2020.12.0-py3-none-any.whl (884 kB)
#      |████████████████████████████████| 884 kB 73.0 MB/s
# Collecting gluoncv<0.9.0,>=0.5.0
#   Downloading gluoncv-0.8.0-py2.py3-none-any.whl (810 kB)
#      |████████████████████████████████| 810 kB 58.7 MB/s
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.1.1-py2.py3-none-manylinux1_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 61.3 MB/s
# Requirement already satisfied: wheel in /usr/local/lib/python3.6/dist-packages (from lightgbm<4.0,>=3.0->autogluon) (0.36.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx<3.0,>=2.3->autogluon) (4.4.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.28->fastparquet==0.4.1->autogluon) (0.31.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2.0,>=1.0.0->autogluon) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas<2.0,>=1.0.0->autogluon) (2018.9)
# Collecting paramiko>=2.4
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 77.3 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.2 MB/s
# Collecting Pillow<=6.2.1
#   Downloading Pillow-6.2.1-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 75.7 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 72.2 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn<0.24,>=0.22.0->autogluon) (1.0.0)
# Collecting thrift>=0.11.0
#   Downloading thrift-0.13.0.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 8.3 MB/s
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon) (1.0.1)
# Collecting autogluon-contrib-nlp
#   Downloading autogluon_contrib_nlp-0.0.1b20201009-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 70.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from autogluon-contrib-nlp->autogluon) (2019.12.20)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from autogluon-contrib-nlp->autogluon) (3.12.4)
# Collecting sacremoses>=0.0.38
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      |████████████████████████████████| 883 kB 70.0 MB/s
# Collecting tokenizers<0.9.0,>=0.7.0
#   Downloading tokenizers-0.8.1-cp36-cp36m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 64.8 MB/s
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting boto3
#   Downloading boto3-1.16.40-py2.py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 68.5 MB/s
# Collecting botocore<1.20.0,>=1.19.40
#   Downloading botocore-1.19.40-py2.py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 57.2 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.2 MB/s
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 50.9 MB/s
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98 kB)
#      |████████████████████████████████| 98 kB 9.6 MB/s
# Collecting flake8
#   Downloading flake8-3.8.4-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.6/dist-packages (from flake8->autogluon-contrib-nlp->autogluon) (3.3.0)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.7.0,>=2.6.0a1
#   Downloading pycodestyle-2.6.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 386 kB/s
# Collecting pyflakes<2.3.0,>=2.2.0
#   Downloading pyflakes-2.2.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 6.6 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata->flake8->autogluon-contrib-nlp->autogluon) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata->flake8->autogluon-contrib-nlp->autogluon) (3.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->autogluon) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->autogluon) (1.3.1)
# Collecting openml
#   Downloading openml-0.11.0.tar.gz (110 kB)
#      |████████████████████████████████| 110 kB 74.2 MB/s
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->catboost<0.25,>=0.23.0->autogluon) (1.3.3)
# Collecting portalocker
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (8.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (20.3.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (1.10.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (1.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (2020.12.5)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 67.2 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-1.4.14-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 4.0 MB/s
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.8.1-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 8.6 MB/s
# Collecting pyaml>=16.9
#   Downloading pyaml-20.4.0-py2.py3-none-any.whl (17 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.94-cp36-cp36m-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 64.4 MB/s
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 8.2 MB/s
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: fastparquet, ConfigSpace, thrift, sacremoses, contextvars, openml, liac-arff, typing
#   Building wheel for fastparquet (setup.py) ... done
#   Created wheel for fastparquet: filename=fastparquet-0.4.1-cp36-cp36m-linux_x86_64.whl size=7114778 sha256=fc62e7ff39b4a2c994d12e6bab285c5b5a564d8c2d1a317d96f270f849b4e3a5
#   Stored in directory: /root/.cache/pip/wheels/8a/c2/8c/3b80e2a78a9932c93ac3fd0c449599c6b1f6fb3ccc4640f331
#   Building wheel for ConfigSpace (setup.py) ... done
#   Created wheel for ConfigSpace: filename=ConfigSpace-0.4.10-cp36-cp36m-linux_x86_64.whl size=2712500 sha256=4dba046ed4efa87d2a2a9c456b660d36a95b8e50731701dbec7a65eeac77e000
#   Stored in directory: /root/.cache/pip/wheels/70/71/a2/00ca7cb0f71294d73e8791d6fe5cd0c7401066ec3b7e1026db
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=345271 sha256=01123286b5f7bdf07f5af61d546f332a88973924454b0bc63799e29fdae4757e
#   Stored in directory: /root/.cache/pip/wheels/e0/38/fc/472fe18756b177b42096961f8bd3ff2dc5c5620ac399fce52d
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893258 sha256=56cc0bdf39c4a43a2fffc420144ba6739f88f2bd74b6866d4a5b7dfc004a1be5
#   Stored in directory: /root/.cache/pip/wheels/49/25/98/cdea9c79b2d9a22ccc59540b1784b67f06b633378e97f58da2
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=8220169c57941c842797aa32af67f6d92fc5478cf105057bf58a2d5b6018fcdb
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
#   Building wheel for openml (setup.py) ... done
#   Created wheel for openml: filename=openml-0.11.0-py3-none-any.whl size=127467 sha256=d39f58b27ad42090726003a40e6d95bf3495cc827d14da474e090ef50f206f3c
#   Stored in directory: /root/.cache/pip/wheels/f2/79/a3/ce317db6149c75c2d68d8502ca12ec8c7281ab9d23dfab4ace
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=9ba1ccb8a610387604b421dfba14156e4e1fdae399087409b84a7833969b0228
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26308 sha256=c00b4d8b0785f828165df8cea1591417861376dad5197ae3520c3a44d680a331
#   Stored in directory: /root/.cache/pip/wheels/5f/63/c2/b85489bbea28cb5d36cfe197244f898428004fa3caa7a23116
# Successfully built fastparquet ConfigSpace thrift sacremoses contextvars openml liac-arff typing
# Installing collected packages: urllib3, jmespath, pyflakes, pycodestyle, portalocker, mccabe, immutables, botocore, yacs, xmltodict, typing, tokenizers, thrift, sentencepiece, sacremoses, sacrebleu, s3transfer, pynacl, pyaml, Pillow, liac-arff, flake8, dask, cryptography, contextvars, cloudpickle, bcrypt, scikit-optimize, paramiko, openml, lightgbm, gluoncv, fastparquet, distributed, ConfigSpace, catboost, boto3, autogluon-contrib-nlp, autogluon
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.11.0 requires cloudpickle==1.3, but you have cloudpickle 1.6.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.10 Pillow-6.2.1 autogluon-0.0.15 autogluon-contrib-nlp-0.0.1b20201009 bcrypt-3.2.0 boto3-1.16.40 botocore-1.19.40 catboost-0.24.3 cloudpickle-1.6.0 contextvars-2.4 cryptography-3.3.1 dask-2020.12.0 distributed-2020.12.0 fastparquet-0.4.1 flake8-3.8.4 gluoncv-0.8.0 immutables-0.14 jmespath-0.10.0 liac-arff-2.5.0 lightgbm-3.1.1 mccabe-0.6.1 openml-0.11.0 paramiko-2.7.2 portalocker-2.0.0 pyaml-20.4.0 pycodestyle-2.6.0 pyflakes-2.2.0 pynacl-1.4.0 s3transfer-0.3.3 sacrebleu-1.4.14 sacremoses-0.0.43 scikit-optimize-0.8.1 sentencepiece-0.1.94 thrift-0.13.0 tokenizers-0.8.1 typing-3.7.4.3 urllib3-1.25.11 xmltodict-0.12.0 yacs-0.1.8

# %%
# !pip install -U ipykernel
# Out:
# Collecting ipykernel
#   Downloading https://files.pythonhosted.org/packages/56/c5/97a972202414c79c28814b1450a31a89777638fb3524e8b5b686a5436abe/ipykernel-5.4.2-py3-none-any.whl (119kB)
#      |████████████████████████████████| 122kB 13.6MB/s
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipykernel) (5.1.1)
# Requirement already satisfied, skipping upgrade: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel) (5.3.5)
# Requirement already satisfied, skipping upgrade: ipython>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel) (5.5.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel) (4.3.3)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel) (20.0.0)
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.6.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel) (4.7.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel) (2.8.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (1.0.18)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (4.8.0)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (2.6.1)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (50.3.2)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (4.4.2)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (0.8.1)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.1.0->ipykernel) (1.15.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.1.0->ipykernel) (0.2.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.0.0->ipykernel) (0.2.5)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel) (0.6.0)
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.4.2 which is incompatible.
# Installing collected packages: ipykernel
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
# Successfully installed ipykernel-5.4.2

# %%
import autogluon as ag
from autogluon import ObjectDetection as task

# %% [markdown]
# https://timebutt.github.io/

# %%
root = '/tmp'
filename_zip = ag.download('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/nfpa.zip',
                        path=root)
filename = ag.unzip(filename_zip, root=root)
# Out:
# Downloading /tmp/nfpa.zip from https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/nfpa.zip...
# VBox(children=(HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=20013), HTML(value=''))), HTML…

# %%
# !ls /tmp/nfpa
# Out:
# Annotations  ImageSets	JPEGImages

# %%
import os
data_root = os.path.join(root, filename)
dataset_train = task.Dataset(data_root, classes=('nfpa',))
# Out:
# >>> create dataset(VOC format)

# %%
from IPython.display import Image
Image(os.path.join(data_root,"JPEGImages/pos-101.jpg"))

# %%
Image(os.path.join(data_root,"JPEGImages/pos-201.jpg"))

# %%
time_limits = 20
epochs = 25
detector = task.fit(dataset_train,
                    num_trials=2,
                    epochs=epochs,
                    lr=ag.Categorical(5e-4, 1e-4),
                    ngpus_per_trial=1,
                    time_limits=time_limits)
# Out:
# scheduler_options: Key 'training_history_callback_delta_secs': Imputing default value 60
# scheduler_options: Key 'delay_get_config': Imputing default value True
#
# Starting Experiments
# Num of Finished Tasks is 0
# Num of Pending Tasks is 2
# scheduler: FIFOScheduler(
# DistributedResourceManager{
# (Remote: Remote REMOTE_ID: 0,
# 	<Remote: 'inproc://172.28.0.2/271/1' processes=1 threads=2, memory=13.65 GB>, Resource: NodeResourceManager(2 CPUs, 1 GPUs))
# })
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Time out (secs) is 20
# Model file not found. Downloading.
# Downloading /root/.mxnet/models/yolo3_mobilenet1.0_coco-66dbbae6.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_mobilenet1.0_coco-66dbbae6.zip...
# 88993KB [00:02, 37980.55KB/s]
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7fafe907e748>, 'net': 'mobilenet1.0', 'lr': 0.0005, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': False, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 0}
# [Epoch 0] Training cost: 52.690, ObjLoss=270.798,BoxCenterLoss=3.040,BoxScaleLoss=1.809,ClassLoss=0.723
# [Epoch 0] Validation: nfpa=0.36474888747616024 mAP=0.36474888747616024
# [Epoch 1] Training cost: 43.503, ObjLoss=14.200,BoxCenterLoss=2.975,BoxScaleLoss=1.301,ClassLoss=0.525
# [Epoch 1] Validation: nfpa=0.49685965197593107 mAP=0.49685965197593107
# [Epoch 2] Training cost: 44.135, ObjLoss=23.214,BoxCenterLoss=3.000,BoxScaleLoss=1.065,ClassLoss=0.416
# [Epoch 2] Validation: nfpa=0.11363636363636365 mAP=0.11363636363636365
# [Epoch 3] Training cost: 47.911, ObjLoss=15.333,BoxCenterLoss=2.862,BoxScaleLoss=0.976,ClassLoss=0.301
# [Epoch 3] Validation: nfpa=0.5480899594399385 mAP=0.5480899594399385
# [Epoch 4] Training cost: 54.649, ObjLoss=10.608,BoxCenterLoss=2.896,BoxScaleLoss=0.982,ClassLoss=0.269
# [Epoch 4] Validation: nfpa=0.5267552363038113 mAP=0.5267552363038113
# [Epoch 5] Training cost: 50.454, ObjLoss=8.618,BoxCenterLoss=2.802,BoxScaleLoss=1.016,ClassLoss=0.238
# [Epoch 5] Validation: nfpa=0.3742657168857886 mAP=0.3742657168857886
# [Epoch 6] Training cost: 51.912, ObjLoss=4.305,BoxCenterLoss=2.909,BoxScaleLoss=1.087,ClassLoss=0.217
# [Epoch 6] Validation: nfpa=0.5394141317592939 mAP=0.5394141317592939
# [Epoch 7] Training cost: 48.441, ObjLoss=3.478,BoxCenterLoss=2.814,BoxScaleLoss=0.960,ClassLoss=0.191
# [Epoch 7] Validation: nfpa=0.6245703826146063 mAP=0.6245703826146063
# [Epoch 8] Training cost: 51.668, ObjLoss=4.309,BoxCenterLoss=2.811,BoxScaleLoss=1.134,ClassLoss=0.196
# [Epoch 8] Validation: nfpa=0.6882388967369204 mAP=0.6882388967369204
# [Epoch 9] Training cost: 47.530, ObjLoss=5.125,BoxCenterLoss=2.794,BoxScaleLoss=0.890,ClassLoss=0.164
# [Epoch 9] Validation: nfpa=0.6280991735537191 mAP=0.6280991735537191
# [Epoch 10] Training cost: 46.912, ObjLoss=3.812,BoxCenterLoss=2.718,BoxScaleLoss=0.880,ClassLoss=0.141
# [Epoch 10] Validation: nfpa=0.5971174639605873 mAP=0.5971174639605873
# [Epoch 11] Training cost: 43.514, ObjLoss=3.527,BoxCenterLoss=2.722,BoxScaleLoss=0.953,ClassLoss=0.153
# [Epoch 11] Validation: nfpa=0.6418531045241574 mAP=0.6418531045241574
# [Epoch 12] Training cost: 45.311, ObjLoss=3.837,BoxCenterLoss=2.771,BoxScaleLoss=1.056,ClassLoss=0.154
# [Epoch 12] Validation: nfpa=0.6339066339066339 mAP=0.6339066339066339
# [Epoch 13] Training cost: 38.780, ObjLoss=3.076,BoxCenterLoss=2.699,BoxScaleLoss=0.972,ClassLoss=0.130
# [Epoch 13] Validation: nfpa=0.6863768168637683 mAP=0.6863768168637683
# [Epoch 14] Training cost: 44.631, ObjLoss=2.862,BoxCenterLoss=2.795,BoxScaleLoss=0.860,ClassLoss=0.126
# [Epoch 14] Validation: nfpa=0.7564654296460319 mAP=0.7564654296460319
# [Epoch 15] Training cost: 46.676, ObjLoss=2.637,BoxCenterLoss=2.712,BoxScaleLoss=1.059,ClassLoss=0.122
# [Epoch 15] Validation: nfpa=0.6852030130089737 mAP=0.6852030130089737
# [Epoch 16] Training cost: 42.702, ObjLoss=2.207,BoxCenterLoss=2.661,BoxScaleLoss=0.912,ClassLoss=0.114
# [Epoch 16] Validation: nfpa=0.6690730725213484 mAP=0.6690730725213484
# [Epoch 17] Training cost: 46.473, ObjLoss=2.850,BoxCenterLoss=2.682,BoxScaleLoss=0.831,ClassLoss=0.114
# [Epoch 17] Validation: nfpa=0.6805194805194805 mAP=0.6805194805194805
# [Epoch 18] Training cost: 49.975, ObjLoss=2.492,BoxCenterLoss=2.666,BoxScaleLoss=0.817,ClassLoss=0.086
# [Epoch 18] Validation: nfpa=0.7695138102982602 mAP=0.7695138102982602
# [Epoch 19] Training cost: 45.990, ObjLoss=2.771,BoxCenterLoss=2.713,BoxScaleLoss=0.926,ClassLoss=0.109
# [Epoch 19] Validation: nfpa=0.6026473274095411 mAP=0.6026473274095411
# [Epoch 20] Training cost: 48.997, ObjLoss=2.616,BoxCenterLoss=2.653,BoxScaleLoss=1.055,ClassLoss=0.114
# [Epoch 20] Validation: nfpa=0.7359532828282828 mAP=0.7359532828282828
# [Epoch 21] Training cost: 43.173, ObjLoss=2.252,BoxCenterLoss=2.683,BoxScaleLoss=0.887,ClassLoss=0.099
# [Epoch 21] Validation: nfpa=0.7415751151963524 mAP=0.7415751151963524
# [Epoch 22] Training cost: 46.905, ObjLoss=2.219,BoxCenterLoss=2.589,BoxScaleLoss=0.772,ClassLoss=0.092
# [Epoch 22] Validation: nfpa=0.7873036054854238 mAP=0.7873036054854238
# [Epoch 23] Training cost: 45.642, ObjLoss=2.017,BoxCenterLoss=2.720,BoxScaleLoss=0.872,ClassLoss=0.082
# [Epoch 23] Validation: nfpa=0.7877278728571833 mAP=0.7877278728571833
# [Epoch 24] Training cost: 45.971, ObjLoss=2.120,BoxCenterLoss=2.632,BoxScaleLoss=0.843,ClassLoss=0.069
# [Epoch 24] Validation: nfpa=0.8023668070066012 mAP=0.8023668070066012
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7fafe6a45e48>, 'net': 'mobilenet1.0', 'lr': 0.0001, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': False, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 1}
# [Epoch 0] Training cost: 46.276, ObjLoss=318.807,BoxCenterLoss=3.087,BoxScaleLoss=2.055,ClassLoss=0.823
# [Epoch 0] Validation: nfpa=0.09090909090909091 mAP=0.09090909090909091
# [Epoch 1] Training cost: 40.553, ObjLoss=10.965,BoxCenterLoss=2.978,BoxScaleLoss=1.584,ClassLoss=0.631
# [Epoch 1] Validation: nfpa=0.28960707158203025 mAP=0.28960707158203025
# [Epoch 2] Training cost: 44.218, ObjLoss=5.653,BoxCenterLoss=3.027,BoxScaleLoss=1.279,ClassLoss=0.561
# [Epoch 2] Validation: nfpa=0.4152312065251471 mAP=0.4152312065251471
# [Epoch 3] Training cost: 38.485, ObjLoss=4.520,BoxCenterLoss=2.951,BoxScaleLoss=1.117,ClassLoss=0.459
# [Epoch 3] Validation: nfpa=0.4165393780363308 mAP=0.4165393780363308
# [Epoch 4] Training cost: 46.543, ObjLoss=4.260,BoxCenterLoss=2.931,BoxScaleLoss=0.988,ClassLoss=0.393
# [Epoch 4] Validation: nfpa=0.5239016450411513 mAP=0.5239016450411513
# [Epoch 5] Training cost: 45.961, ObjLoss=3.801,BoxCenterLoss=2.889,BoxScaleLoss=1.046,ClassLoss=0.341
# [Epoch 5] Validation: nfpa=0.5082030138137861 mAP=0.5082030138137861
# [Epoch 6] Training cost: 50.286, ObjLoss=3.774,BoxCenterLoss=2.835,BoxScaleLoss=0.957,ClassLoss=0.307
# [Epoch 6] Validation: nfpa=0.5208983805935793 mAP=0.5208983805935793
# [Epoch 7] Training cost: 44.758, ObjLoss=3.471,BoxCenterLoss=2.840,BoxScaleLoss=0.936,ClassLoss=0.282
# [Epoch 7] Validation: nfpa=0.5542850404726202 mAP=0.5542850404726202
# [Epoch 8] Training cost: 43.877, ObjLoss=3.432,BoxCenterLoss=2.836,BoxScaleLoss=1.079,ClassLoss=0.311
# [Epoch 8] Validation: nfpa=0.5725179277244494 mAP=0.5725179277244494
# [Epoch 9] Training cost: 51.897, ObjLoss=2.949,BoxCenterLoss=2.803,BoxScaleLoss=0.859,ClassLoss=0.235
# [Epoch 9] Validation: nfpa=0.5754319721090249 mAP=0.5754319721090249
# [Epoch 10] Training cost: 49.552, ObjLoss=2.982,BoxCenterLoss=2.820,BoxScaleLoss=0.949,ClassLoss=0.238
# [Epoch 10] Validation: nfpa=0.5079180950980287 mAP=0.5079180950980287
# [Epoch 11] Training cost: 47.584, ObjLoss=3.055,BoxCenterLoss=2.675,BoxScaleLoss=0.981,ClassLoss=0.217
# [Epoch 11] Validation: nfpa=0.6169102337253202 mAP=0.6169102337253202
# [Epoch 12] Training cost: 47.284, ObjLoss=2.792,BoxCenterLoss=2.744,BoxScaleLoss=0.999,ClassLoss=0.229
# [Epoch 12] Validation: nfpa=0.6300260561445383 mAP=0.6300260561445383
# [Epoch 13] Training cost: 41.968, ObjLoss=2.933,BoxCenterLoss=2.822,BoxScaleLoss=0.959,ClassLoss=0.233
# [Epoch 13] Validation: nfpa=0.5999219494010201 mAP=0.5999219494010201
# [Epoch 14] Training cost: 53.811, ObjLoss=2.887,BoxCenterLoss=2.815,BoxScaleLoss=0.855,ClassLoss=0.179
# [Epoch 14] Validation: nfpa=0.6333845167878231 mAP=0.6333845167878231
# [Epoch 15] Training cost: 46.086, ObjLoss=2.512,BoxCenterLoss=2.688,BoxScaleLoss=0.903,ClassLoss=0.181
# [Epoch 15] Validation: nfpa=0.6824042703759037 mAP=0.6824042703759037
# [Epoch 16] Training cost: 43.713, ObjLoss=2.225,BoxCenterLoss=2.745,BoxScaleLoss=0.844,ClassLoss=0.158
# [Epoch 16] Validation: nfpa=0.7092555521452633 mAP=0.7092555521452633
# [Epoch 17] Training cost: 44.142, ObjLoss=2.708,BoxCenterLoss=2.766,BoxScaleLoss=0.859,ClassLoss=0.150
# [Epoch 17] Validation: nfpa=0.7272476076959212 mAP=0.7272476076959212
# [Epoch 18] Training cost: 49.743, ObjLoss=2.778,BoxCenterLoss=2.692,BoxScaleLoss=0.776,ClassLoss=0.124
# [Epoch 18] Validation: nfpa=0.7267881859895338 mAP=0.7267881859895338
# [Epoch 19] Training cost: 42.953, ObjLoss=2.206,BoxCenterLoss=2.632,BoxScaleLoss=0.745,ClassLoss=0.126
# [Epoch 19] Validation: nfpa=0.740862620714988 mAP=0.740862620714988
# [Epoch 20] Training cost: 40.642, ObjLoss=2.260,BoxCenterLoss=2.674,BoxScaleLoss=0.870,ClassLoss=0.141
# [Epoch 20] Validation: nfpa=0.6365807852494274 mAP=0.6365807852494274
# [Epoch 21] Training cost: 50.490, ObjLoss=2.255,BoxCenterLoss=2.736,BoxScaleLoss=0.872,ClassLoss=0.132
# [Epoch 21] Validation: nfpa=0.7503419555582833 mAP=0.7503419555582833
# [Epoch 22] Training cost: 49.361, ObjLoss=2.229,BoxCenterLoss=2.643,BoxScaleLoss=0.742,ClassLoss=0.104
# [Epoch 22] Validation: nfpa=0.76305933835985 mAP=0.76305933835985
# [Epoch 23] Training cost: 38.167, ObjLoss=2.126,BoxCenterLoss=2.708,BoxScaleLoss=0.711,ClassLoss=0.105
# [Epoch 23] Validation: nfpa=0.6557583557179044 mAP=0.6557583557179044
# [Epoch 24] Training cost: 47.706, ObjLoss=2.090,BoxCenterLoss=2.643,BoxScaleLoss=0.734,ClassLoss=0.097
# [Epoch 24] Validation: nfpa=0.7603517958060543 mAP=0.7603517958060543
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7fafe9902f28>, 'net': 'mobilenet1.0', 'lr': 0.0005, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': True, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 2}
# [Epoch 0] Training cost: 55.086, ObjLoss=457.908,BoxCenterLoss=2.986,BoxScaleLoss=1.573,ClassLoss=0.722
# [Epoch 1] Training cost: 60.894, ObjLoss=18.813,BoxCenterLoss=2.975,BoxScaleLoss=1.092,ClassLoss=0.476
# [Epoch 2] Training cost: 61.064, ObjLoss=6.232,BoxCenterLoss=2.992,BoxScaleLoss=1.024,ClassLoss=0.361
# [Epoch 3] Training cost: 52.063, ObjLoss=10.486,BoxCenterLoss=2.936,BoxScaleLoss=0.967,ClassLoss=0.297
# [Epoch 4] Training cost: 64.468, ObjLoss=4.573,BoxCenterLoss=2.901,BoxScaleLoss=1.027,ClassLoss=0.238
# [Epoch 5] Training cost: 58.034, ObjLoss=4.141,BoxCenterLoss=2.861,BoxScaleLoss=1.090,ClassLoss=0.196
# [Epoch 6] Training cost: 56.261, ObjLoss=3.571,BoxCenterLoss=2.866,BoxScaleLoss=0.972,ClassLoss=0.177
# [Epoch 7] Training cost: 54.852, ObjLoss=3.693,BoxCenterLoss=2.825,BoxScaleLoss=0.968,ClassLoss=0.159
# [Epoch 8] Training cost: 51.648, ObjLoss=4.792,BoxCenterLoss=2.862,BoxScaleLoss=0.962,ClassLoss=0.162
# [Epoch 9] Training cost: 61.577, ObjLoss=4.058,BoxCenterLoss=2.822,BoxScaleLoss=0.835,ClassLoss=0.141
# [Epoch 10] Training cost: 48.439, ObjLoss=2.746,BoxCenterLoss=2.655,BoxScaleLoss=0.961,ClassLoss=0.114
# [Epoch 11] Training cost: 58.506, ObjLoss=5.058,BoxCenterLoss=2.758,BoxScaleLoss=1.095,ClassLoss=0.118
# [Epoch 12] Training cost: 57.856, ObjLoss=3.388,BoxCenterLoss=2.763,BoxScaleLoss=0.931,ClassLoss=0.111
# [Epoch 13] Training cost: 55.645, ObjLoss=4.530,BoxCenterLoss=2.674,BoxScaleLoss=0.980,ClassLoss=0.094
# [Epoch 14] Training cost: 65.467, ObjLoss=3.825,BoxCenterLoss=2.753,BoxScaleLoss=0.849,ClassLoss=0.093
# [Epoch 15] Training cost: 54.202, ObjLoss=2.785,BoxCenterLoss=2.659,BoxScaleLoss=0.903,ClassLoss=0.103
# [Epoch 16] Training cost: 49.689, ObjLoss=2.514,BoxCenterLoss=2.680,BoxScaleLoss=0.943,ClassLoss=0.093
# [Epoch 17] Training cost: 65.102, ObjLoss=2.737,BoxCenterLoss=2.700,BoxScaleLoss=0.736,ClassLoss=0.081
# [Epoch 18] Training cost: 54.313, ObjLoss=2.209,BoxCenterLoss=2.737,BoxScaleLoss=0.841,ClassLoss=0.072
# [Epoch 19] Training cost: 54.621, ObjLoss=2.184,BoxCenterLoss=2.667,BoxScaleLoss=0.863,ClassLoss=0.074
# [Epoch 20] Training cost: 62.024, ObjLoss=2.717,BoxCenterLoss=2.812,BoxScaleLoss=0.780,ClassLoss=0.076
# [Epoch 21] Training cost: 54.792, ObjLoss=2.834,BoxCenterLoss=2.700,BoxScaleLoss=0.851,ClassLoss=0.083
# [Epoch 22] Training cost: 58.128, ObjLoss=3.099,BoxCenterLoss=2.701,BoxScaleLoss=0.862,ClassLoss=0.064
# [Epoch 23] Training cost: 58.240, ObjLoss=3.635,BoxCenterLoss=2.763,BoxScaleLoss=0.808,ClassLoss=0.087
# [Epoch 24] Training cost: 59.124, ObjLoss=2.648,BoxCenterLoss=2.626,BoxScaleLoss=0.813,ClassLoss=0.075
# Saving Training Curve in checkpoint/plot_training_curves.png
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> finish model fitting
# The best config: {'lr▁choice': 0, 'net▁choice': 0}

# %%
dataset_test = task.Dataset(data_root, index_file_name='test', classes=('nfpa',))

test_map = detector.evaluate(dataset_test)
print("mAP on test dataset: {}".format(test_map[1][1]))
# Out:
# >>> create dataset(VOC format)
# mAP on test dataset: 0.810909090909091

# %%
image = 'pos-230.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
image = 'pos-23.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
image = 'pos-201.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
savefile = 'model.pkl'
detector.save(savefile)

from autogluon import Detector
new_detector = Detector.load(savefile)

# %%
# !ls
# Out:
# checkpoint	   model.pkl	yolo3_mobilenet1.0_custom_train.log
# dask-worker-space  sample_data
